# %% [markdown]
# # 1: Programming
# Kaitlin Luu

# %% [markdown]
# ### Question 1

# %% [markdown]
# ![jobs](Q1_image.png)

# %% [markdown]
# **Suprising findings**
#
# The first thing I noticed was that Data Scientist has the highest job outlook in my list, which was a reassuring finding. I found it interesting that financial analyst and budget analyst have such different salaries and job outlook even though their descriptions are pretty similar. I also thought it was interesting that you need a few years of work experience to become a information security analyst while the other jobs here require none.

# %% [markdown]
# **Ranking**
#
# 1) Data Scientist - I like analyzing data and transforming observations into insights that can be used to solve real-world problems.
# 2) Statistician - I like the intersection between statistics and public health, so biostatistics in particular really interests me.
# 3) Information Security Analyst - I find cybersecurity interesting, and I want to help protect people from malware.
# 4) Web Developer/Digital Designer - I like UI/UX design and creating web applications while thinking about how users can interact with software.
# 5) Epidemiologist - I find epidemiology interesting, but I am unsure about getting a MPH.
# 6) Market Research Analyst - I like using data to achieve business insights, but I would prefer a slightly higher salary.
# 7) Software Developer/Quality Assurance Analyst - I like using programming to solve problems, but I would prefer something less computer science heavy.
# 8) Financial Analyst - I like the idea of helping businesses make better financial decisions, but I do not know if finance interests me that much.
# 9) Budget Analyst - Similar reason to financial analyst, and I would prefer the job outlook to be higher.

# %% [markdown]
# ### Question 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Parts 1-7

x = np.linspace(0, 1, 50)
y = np.log(x)
z = np.exp(x)

plt.scatter(x,y, label='Nautral Log')
plt.scatter(x,z, label='Exponential')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower right')
plt.title("Natural Log and Exponential Functions")
plt.show()

plt.show()
# Out:
# /tmp/ipykernel_200/2495793220.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)

# %%
# Parts 8-10

x = np.linspace(-6.5, 6.5, 100)
y = np.sin(x)
z = np.cos(x)

plt.scatter(x,y)
plt.scatter(x,z)
plt.show()

# %%
# Parts 11 and 12

plt.plot(x,y, label='sine')
plt.plot(x,z, label='cosine')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower left')
plt.title('Sine and Cosine Functions')
plt.show()
